# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


df = pd.read_csv('/content/cars_price.csv')
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# 1            two  convertible          rwd           front        88.6  ...
# 2            two    hatchback          rwd           front        94.5  ...
# 3           four        sedan          fwd           front        99.8  ...
# 4           four        sedan          4wd           front        99.4  ...
# ..           ...          ...          ...             ...         ...  ...
# 200         four        sedan          rwd           front       109.1  ...
# 201         four        sedan          rwd           front       109.1  ...
# 202         four        sedan          rwd           front       109.1  ...
# 203         four        sedan          rwd           front       109.1  ...
# 204         four        sedan          rwd           front       109.1  ...
#
#      engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0            130         mpfi  3.47    2.68               9.0        111
# 1            130         mpfi  3.47    2.68               9.0        111
# 2            152         mpfi  2.68    3.47               9.0        154
# 3            109         mpfi  3.19     3.4              10.0        102
# 4            136         mpfi  3.19     3.4               8.0        115
# ..           ...          ...   ...     ...               ...        ...
# 200          141         mpfi  3.78    3.15               9.5        114
# 201          141         mpfi  3.78    3.15               8.7        160
# 202          173         mpfi  3.58    2.87               8.8        134
# 203          145          idi  3.01     3.4              23.0        106
# 204          141         mpfi  3.78    3.15               9.5        114
#
#      peak-rpm city-mpg highway-mpg  price
# 0        5000       21          27  13495
# 1        5000       21          27  16500
# 2        5000       19          26  16500
# 3        5500       24          30  13950
# 4        5500       18          22  17450
# ..        ...      ...         ...    ...
# 200      5400       23          28  16845
# 201      5300       19          25  19045
# 202      5500       18          23  21485
# 203      4800       26          27  22470
# 204      5400       19          25  22625
#
# [205 rows x 26 columns]

# %%
df.shape
# Out:
# (205, 26)

# %%
df.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# min    1488.000000    61.000000           7.000000   13.000000    16.000000
# 25%    2145.000000    97.000000           8.600000   19.000000    25.000000
# 50%    2414.000000   120.000000           9.000000   24.000000    30.000000
# 75%    2935.000000   141.000000           9.400000   30.000000    34.000000
# max    4066.000000   326.000000          23.000000   49.000000    54.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
#  16  engine-size        205 non-null    int64
#  17  fuel-system        205 non-null    object
#  18  bore               205 non-null    object
#  19  stroke             205 non-null    object
#  20  compression-ratio  205 non-null    float64
#  21  horsepower         205 non-null    object
#  22  peak-rpm           205 non-null    object
#  23  city-mpg           205 non-null    int64
#  24  highway-mpg        205 non-null    int64
#  25  price              205 non-null    object
# dtypes: float64(5), int64(5), object(16)
# memory usage: 41.8+ KB

# %%
df=df.replace('?',np.nan)
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3               NaN  alfa-romero       gas        std
# 1            3               NaN  alfa-romero       gas        std
# 2            1               NaN  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# 1            two  convertible          rwd           front        88.6  ...
# 2            two    hatchback          rwd           front        94.5  ...
# 3           four        sedan          fwd           front        99.8  ...
# 4           four        sedan          4wd           front        99.4  ...
# ..           ...          ...          ...             ...         ...  ...
# 200         four        sedan          rwd           front       109.1  ...
# 201         four        sedan          rwd           front       109.1  ...
# 202         four        sedan          rwd           front       109.1  ...
# 203         four        sedan          rwd           front       109.1  ...
# 204         four        sedan          rwd           front       109.1  ...
#
#      engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0            130         mpfi  3.47    2.68               9.0        111
# 1            130         mpfi  3.47    2.68               9.0        111
# 2            152         mpfi  2.68    3.47               9.0        154
# 3            109         mpfi  3.19     3.4              10.0        102
# 4            136         mpfi  3.19     3.4               8.0        115
# ..           ...          ...   ...     ...               ...        ...
# 200          141         mpfi  3.78    3.15               9.5        114
# 201          141         mpfi  3.78    3.15               8.7        160
# 202          173         mpfi  3.58    2.87               8.8        134
# 203          145          idi  3.01     3.4              23.0        106
# 204          141         mpfi  3.78    3.15               9.5        114
#
#      peak-rpm city-mpg highway-mpg  price
# 0        5000       21          27  13495
# 1        5000       21          27  16500
# 2        5000       19          26  16500
# 3        5500       24          30  13950
# 4        5500       18          22  17450
# ..        ...      ...         ...    ...
# 200      5400       23          28  16845
# 201      5300       19          25  19045
# 202      5500       18          23  21485
# 203      4800       26          27  22470
# 204      5400       19          25  22625
#
# [205 rows x 26 columns]

# %%
df.dropna(inplace=True)
df.reset_index(drop=True)
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 0            2               164   audi       gas        std         four
# 1            2               164   audi       gas        std         four
# 2            1               158   audi       gas        std         four
# 3            1               158   audi       gas      turbo         four
# 4            2               192    bmw       gas        std          two
# ..         ...               ...    ...       ...        ...          ...
# 154         -1                95  volvo       gas        std         four
# 155         -1                95  volvo       gas      turbo         four
# 156         -1                95  volvo       gas        std         four
# 157         -1                95  volvo    diesel      turbo         four
# 158         -1                95  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0        sedan          fwd           front        99.8  ...          109
# 1        sedan          4wd           front        99.4  ...          136
# 2        sedan          fwd           front       105.8  ...          136
# 3        sedan          fwd           front       105.8  ...          131
# 4        sedan          rwd           front       101.2  ...          108
# ..         ...          ...             ...         ...  ...          ...
# 154      sedan          rwd           front       109.1  ...          141
# 155      sedan          rwd           front       109.1  ...          141
# 156      sedan          rwd           front       109.1  ...          173
# 157      sedan          rwd           front       109.1  ...          145
# 158      sedan          rwd           front       109.1  ...          141
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# 0           mpfi  3.19     3.4              10.0        102      5500
# 1           mpfi  3.19     3.4               8.0        115      5500
# 2           mpfi  3.19     3.4               8.5        110      5500
# 3           mpfi  3.13     3.4               8.3        140      5500
# 4           mpfi   3.5     2.8               8.8        101      5800
# ..           ...   ...     ...               ...        ...       ...
# 154         mpfi  3.78    3.15               9.5        114      5400
# 155         mpfi  3.78    3.15               8.7        160      5300
# 156         mpfi  3.58    2.87               8.8        134      5500
# 157          idi  3.01     3.4              23.0        106      4800
# 158         mpfi  3.78    3.15               9.5        114      5400
#
#     city-mpg highway-mpg  price
# 0         24          30  13950
# 1         18          22  17450
# 2         19          25  17710
# 3         17          20  23875
# 4         23          29  16430
# ..       ...         ...    ...
# 154       23          28  16845
# 155       19          25  19045
# 156       18          23  21485
# 157       26          27  22470
# 158       19          25  22625
#
# [159 rows x 26 columns]

# %%
df.head()
# Out:
#     symboling normalized-losses  make fuel-type aspiration num-of-doors  \
# 3           2               164  audi       gas        std         four
# 4           2               164  audi       gas        std         four
# 6           1               158  audi       gas        std         four
# 8           1               158  audi       gas      turbo         four
# 10          2               192   bmw       gas        std          two
#
#    body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 3       sedan          fwd           front        99.8  ...          109
# 4       sedan          4wd           front        99.4  ...          136
# 6       sedan          fwd           front       105.8  ...          136
# 8       sedan          fwd           front       105.8  ...          131
# 10      sedan          rwd           front       101.2  ...          108
#
#     fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 3          mpfi  3.19     3.4              10.0        102      5500       24
# 4          mpfi  3.19     3.4               8.0        115      5500       18
# 6          mpfi  3.19     3.4               8.5        110      5500       19
# 8          mpfi  3.13     3.4               8.3        140      5500       17
# 10         mpfi   3.5     2.8               8.8        101      5800       23
#
#    highway-mpg  price
# 3           30  13950
# 4           22  17450
# 6           25  17710
# 8           20  23875
# 10          29  16430
#
# [5 rows x 26 columns]

# %%
X=df.iloc[:,1:]
y=df.iloc[:,0]

# %% [markdown]
# **visualization**

# %%
sns.pairplot(df)
plt.show()

# %%
def dummies(x,df):
    temp = pd.get_dummies(df[x], drop_first = True)
    df = pd.concat([df, temp], axis = 1)
    df.drop([x], axis = 1, inplace = True)
    return df
# Applying the function to the cars_lr
df = dummies('make',df)
df = dummies('fuel-type',df)
df = dummies('aspiration',df)
df = dummies('num-of-doors',df)
df = dummies('body-style',df)
df = dummies('drive-wheels',df)
df = dummies('engine-location',df)
df = dummies('fuel-system',df)
df = dummies('engine-type',df)
df = dummies('num-of-cylinders',df)

# %%
first_column = df.pop('price')
  

df.insert(0, 'price', first_column)

# %%
df
# Out:
#      price  symboling normalized-losses  wheel-base  length  width  height  \
# 3    13950          2               164        99.8   176.6   66.2    54.3
# 4    17450          2               164        99.4   176.6   66.4    54.3
# 6    17710          1               158       105.8   192.7   71.4    55.7
# 8    23875          1               158       105.8   192.7   71.4    55.9
# 10   16430          2               192       101.2   176.8   64.8    54.3
# ..     ...        ...               ...         ...     ...    ...     ...
# 200  16845         -1                95       109.1   188.8   68.9    55.5
# 201  19045         -1                95       109.1   188.8   68.8    55.5
# 202  21485         -1                95       109.1   188.8   68.9    55.5
# 203  22470         -1                95       109.1   188.8   68.9    55.5
# 204  22625         -1                95       109.1   188.8   68.9    55.5
#
#      curb-weight  engine-size  bore  ... mpfi  spdi  l ohc  ohcf  ohcv  five  \
# 3           2337          109  3.19  ...    1     0  0   1     0     0     0
# 4           2824          136  3.19  ...    1     0  0   1     0     0     1
# 6           2844          136  3.19  ...    1     0  0   1     0     0     1
# 8           3086          131  3.13  ...    1     0  0   1     0     0     1
# 10          2395          108   3.5  ...    1     0  0   1     0     0     0
# ..           ...          ...   ...  ...  ...   ... ..  ..   ...   ...   ...
# 200         2952          141  3.78  ...    1     0  0   1     0     0     0
# 201         3049          141  3.78  ...    1     0  0   1     0     0     0
# 202         3012          173  3.58  ...    1     0  0   0     0     1     0
# 203         3217          145  3.01  ...    0     0  0   1     0     0     0
# 204         3062          141  3.78  ...    1     0  0   1     0     0     0
#
#      four  six  three
# 3       1    0      0
# 4       0    0      0
# 6       0    0      0
# 8       0    0      0
# 10      1    0      0
# ..    ...  ...    ...
# 200     1    0      0
# 201     1    0      0
# 202     0    1      0
# 203     0    1      0
# 204     1    0      0
#
# [159 rows x 55 columns]

# %% [markdown]
# Train_Test_Split

# %%
X=df.iloc[:,1:]
y=df.iloc[:,0]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
plt.figure(figsize = (30, 25))
sns.heatmap(X_train.corr(), annot = True, cmap="PiYG")
plt.show()

# %%
df=df.drop(["porsche"],axis=1)

# %% [markdown]
# Linear *Regresion*

# %%
from sklearn.linear_model import LinearRegression

# %%
linreg=LinearRegression(positive=bool)
linreg.fit(X_train,y_train)
LinearRegression()
# Out:
# LinearRegression()

# %%
linreg.score(X_train,y_train)
# Out:
# 0.9492630667253936

# %%
linreg.score(X_test,y_test)
# Out:
# 0.8511987391778814

# %% [markdown]
# Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtr=DecisionTreeRegressor(max_depth=10,random_state=10)

# %%
dtr.fit(X_train,y_train)
DecisionTreeRegressor
# Out:
# sklearn.tree._classes.DecisionTreeRegressor

# %%
print(dtr.score(X_train,y_train))
# Out:
# 0.9984099513572218

# %%
print(dtr.score(X_test,y_test))
# Out:
# 0.8769409473114727

# %% [markdown]
# Random **Forest**

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr=RandomForestRegressor(max_depth=5,min_samples_split=2)

# %%
rfr.fit(X_train,y_train)
# Out:
# RandomForestRegressor(max_depth=5)

# %%
print(rfr.score(X_train,y_train))
# Out:
# 0.9666607292438822

# %%
print(rfr.score(X_test,y_test))
# Out:
# 0.9069027791866477

# %% [markdown]
# Ridge *Regression* **

# %%
from sklearn.linear_model import Ridge

# %%
Ridge=Ridge()

# %%
Ridge.fit(X_train,y_train)
# Out:
# Ridge()

# %%
print(Ridge.score(X_train,y_train))
# Out:
# 0.9599153508207816

# %%
print(Ridge.score(X_test,y_test))
# Out:
# 0.8806614678791718

# %% [markdown]
# Lasso **Regression**

# %%
from sklearn import linear_model

# %%
clf = linear_model.Lasso(alpha=0.1)

# %%
clf.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.598e+07, tolerance: 4.231e+05
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# Lasso(alpha=0.1)

# %%
print(clf.score(X_train,y_train))
# Out:
# 0.9740092284105089

# %%
print(clf.score(X_test,y_test))
# Out:
# 0.9203400221806047

# %% [markdown]
# Final_Model
#
# Ridge *Regression* **

# %%
from sklearn.linear_model import Ridge

# %%
Ridge=Ridge()

# %%
Ridge.fit(X_train,y_train)
# Out:
# Ridge()

# %%
print(Ridge.score(X_train,y_train))
# Out:
# 0.9599153508207816

# %%
print(Ridge.score(X_test,y_test))
# Out:
# 0.8806614678791718

# %% [markdown]
# Mean Squared  Error

# %%
 from sklearn.metrics import mean_squared_error

# %%
y_pred=Ridge.predict(X_test)

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 4516843.33353326

# %% [markdown]
# Median Absolute Error

# %%
from sklearn.metrics import median_absolute_error

# %%
y_pred=Ridge.predict(X_test)

# %%
 median_absolute_error(y_test, y_pred)
# Out:
# 1231.1034115454595

# %% [markdown]
# R2 Score

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8806614678791718
